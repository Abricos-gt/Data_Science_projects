# %% [markdown]
# # Titanic - Machine Learning from Disaster

# %% [markdown]
# # Project 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_
